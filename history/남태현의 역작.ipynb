# %%
# 크롤링 작업을 위한 라이브러리 임포트
from bs4 import BeautifulSoup as bs
from selenium import webdriver
import requests
import time   # 코드 진행 지연을 위한 time 임포트
from selenium.webdriver.common.by import By   # 2022년 7월 이후 selenium 업데이트로 인한 xpath 추적 임포트
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
region = str(input())
page  = int(input())

driver = webdriver.Chrome("chromedriver")
time.sleep(1)
driver.get('https://map.kakao.com/')
time.sleep(2)
driver.find_element(By.XPATH, '//*[@id="search.keyword.query"]').send_keys('%s 식당\n' % region)
time.sleep(7)

### 10초 간 지도 화면 수동으로 클릭해야합니다!!

driver.find_element(By.XPATH, '//*[@id="info.search.place.sort"]/li[1]/a').send_keys(Keys.ENTER)
time.sleep(2)

n_list = []
s_list = []
a_list = []
ka_dict = {}



#######################################


for j in range(page//5):
    source = driver.page_source
    parsed_source = bs(source, 'html.parser')

    names_div_list = parsed_source.find_all("li",class_ = 'PlaceItem clickArea')
    names_span_list = parsed_source.find_all('span', class_ = 'screen_out')
    span_names = names_span_list[1:31:2]
    for i in range(len(span_names)):
        names = span_names[i].text
        n_list.append(names)

    
    div_scores = parsed_source.find_all('em', class_ = "num")
    del div_scores[-1]
    for i in range(len(div_scores)):
        scores = div_scores[i].text
        s_list.append(scores)
    
    
    div_address = parsed_source.find_all('div', class_ = "addr")
    for i in range(len(div_address)):
        address = div_address[i].text.replace('\n','').split('(지번)')[0]
        a_list.append(address)
    
    time.sleep(3)
    for i in range(2,7):
        time.sleep(1)
        if i == 6:
            driver.find_element(By.XPATH,'//*[@id="info.search.page.next"]').send_keys(Keys.ENTER)
            time.sleep(2)
        else:
            driver.find_element(By.XPATH,'//*[@id="info.search.page.no%s"]' % i).send_keys(Keys.ENTER)
            time.sleep(2)

        source = driver.page_source
        parsed_source = bs(source, 'html.parser')

        names_div_list = parsed_source.find_all("li",class_ = 'PlaceItem clickArea')
        names_span_list = parsed_source.find_all('span', class_ = 'screen_out')
        span_names = names_span_list[1:31:2]
        for i in range(len(span_names)):
            names = span_names[i].text
            n_list.append(names)
    
    
        div_scores = parsed_source.find_all('em', class_ = "num")
        del div_scores[-1]
        for i in range(len(div_scores)):
            scores = div_scores[i].text
            s_list.append(scores)
        
    
        div_address = parsed_source.find_all('div', class_ = "addr")
        for i in range(len(div_address)):
            address = div_address[i].text.replace('\n','').split('(지번)')[0]
            a_list.append(address)
    
        time.sleep(2)

        
for k in range(2,(page%5+1)):
    driver.find_element(By.XPATH,'//*[@id="info.search.page.no%s"]' % k).send_keys(Keys.ENTER)
    time.sleep(2)
    
    source = driver.page_source
    parsed_source = bs(source, 'html.parser')

    names_div_list = parsed_source.find_all("li",class_ = 'PlaceItem clickArea')
    names_span_list = parsed_source.find_all('span', class_ = 'screen_out')
    span_names = names_span_list[1:31:2]
    for i in range(len(span_names)):
        names = span_names[i].text
        n_list.append(names)
    
    
    div_scores = parsed_source.find_all('em', class_ = "num")
    del div_scores[-1]
    for i in range(len(div_scores)):
        scores = div_scores[i].text
        s_list.append(scores)
        
    
    div_address = parsed_source.find_all('div', class_ = "addr")
    for i in range(len(div_address)):
        address = div_address[i].text.replace('\n','').split('(지번)')[0]
        a_list.append(address)
    
    time.sleep(2)

for i in range(len(n_list)):
    ka_dict[i] = (n_list[i], s_list[i], a_list[i])

print(ka_dict)
# Out:
# 경기도
# 8
# {0: ('카페대너리스', '3.8', '경기 남양주시 조안면 북한강로 914'), 1: ('더티트렁크', '2.6', '경기 파주시 지목로 114'), 2: ('고기리막국수', '3.6', '경기 용인시 수지구 이종무로 157'), 3: ('레드브릿지', '3.3', '경기 파주시 광탄면 기산로 329 2층'), 4: ('가보정 1관', '3.2', '경기 수원시 팔달구 장다리로 282'), 5: ('본수원갈비 본점', '2.9', '경기 수원시 팔달구 중부대로223번길 41'), 6: ('보나리베카페', '4.1', '경기 남양주시 불암산로39번길 9-2 1,2층'), 7: ('어로프슬라이스피스', '3.1', '경기 용인시 처인구 백령로 47'), 8: ('오랑주리', '3.0', '경기 양주시 백석읍 기산로 423-19'), 9: ('장어의꿈', '3.5', '경기 남양주시 순화궁로 492-6 1층'), 10: ('반구정나루터집', '3.4', '경기 파주시 문산읍 반구정로85번길 13'), 11: ('리버레인', '4.2', '경기 가평군 청평면 북한강로 2141'), 12: ('테라로사 서종점', '3.7', '경기 양평군 서종면 북한강로 992'), 13: ('카페아를', '2.9', '경기 의정부시 동일로 204'), 14: ('파크프리베', '2.9', '경기 의정부시 동일로192번길 28-27'), 15: ('몬떼델피노', '3.3', '경기 김포시 양촌읍 김포한강6로 49-19'), 16: ('베이커리 씨어터', '3.3', '경기 남양주시 화도읍 경춘로2696번길 4-15 1동 1층'), 17: ('모아니', '', '경기 성남시 분당구 쇳골로 116 1층'), 18: ('이진상회', '3.6', '경기 이천시 마장면 서이천로 648 5동 1, 2층'), 19: ('일산칼국수 본점', '4.0', '경기 고양시 일산동구 경의로 467 1층'), 20: ('스페이스작', '3.1', '경기 부천시 까치로20번길 13-7 1~4층'), 21: ('목향원', '3.0', '경기 남양주시 덕릉로1071번길 34-12'), 22: ('갈릴리농원 본관', '3.6', '경기 파주시 탄현면 방촌로 1196'), 23: ('망향비빔국수 궁평본점', '3.8', '경기 연천군 청산면 궁평로 5'), 24: ('두물머리연핫도그', '3.5', '경기 양평군 양서면 두물머리길 103-8 1층'), 25: ('청춘조개 본점', '4.2', '경기 시흥시 오이도로 199-1 1,2층'), 26: ('산골농원', '2.1', '경기 가평군 설악면 어비산길99번길 75-7'), 27: ('청평호반닭갈비막국수', '4.3', '경기 가평군 청평면 강변로 45-7 청평호반닭갈비막국수'), 28: ('강강술래 늘봄농원점', '3.3', '경기 고양시 덕양구 호국로 1526-3 1층'), 29: ('유치회관', '3.4', '경기 수원시 팔달구 효원로292번길 67'), 30: ('나인블럭 뷰팔당점', '2.9', '경기 남양주시 와부읍 다산로 56'), 31: ('카자구루마', '3.6', '경기 수원시 팔달구 신풍로23번길 61 1층'), 32: ('갈비1987', '4.0', '경기 포천시 이동면 화동로 2065-1 1층'), 33: ('동탄 화성카페 어반리st 맛집', '3.9', '경기 화성시 장지로 60-12 장지동'), 34: ('팔당초계국수 본점', '2.6', '경기 남양주시 와부읍 다산로 43'), 35: ('김삿갓밥집', '3.7', '경기 남양주시 화도읍 경춘로 2483 1층'), 36: ('비루개', '2.5', '경기 남양주시 별내면 용암비루개길 219-88 1층'), 37: ('임금님쌀밥집', '3.1', '경기 이천시 신둔면 경충대로 3134'), 38: ('행주산성원조국수집', '3.4', '경기 고양시 덕양구 행주로17번길 10'), 39: ('낙선재', '3.4', '경기 광주시 남한산성면 불당길 101'), 40: ('조개포차', '4.7', '경기 시흥시 오이도로 215'), 41: ('늘솜당', '3.0', '경기 시흥시 하우로122번길 50-3'), 42: ('만수정 본점', '3.2', '경기 용인시 기흥구 신정로 270-4'), 43: ('트윈트리', '3.2', '경기 남양주시 고산로126번길 33-8'), 44: ('앤드테라스 식사점', '3.4', '경기 고양시 일산동구 위시티1로 6-19'), 45: ('동동국수집', '3.6', '경기 남양주시 와부읍 경강로 908'), 46: ('진미통닭', '3.0', '경기 수원시 팔달구 정조로800번길 21 1,2층'), 47: ('김네집', '3.6', '경기 평택시 중앙시장로25번길 15 1,2층'), 48: ('포폴로피자 PIZZERIA DEL POPOLO', '', '경기 고양시 일산동구 정발산로 43-20 센트럴프라자 1층 102, 103호'), 49: ('나랏님이천쌀밥 본관', '2.0', '경기 이천시 경충대로 3052'), 50: ('허기숙할머니 원조오뎅식당 의정부본점', '3.4', '경기 의정부시 호국로1309번길 7'), 51: ('북한강막국수닭갈비', '4.0', '경기 남양주시 조안면 북한강로 908'), 52: ('미가훠궈양고기', '3.9', '경기 용인시 수지구 풍덕천로140번길 15 1층'), 53: ('설악막국수춘천닭갈비', '4.1', '경기 가평군 설악면 신천중앙로 159'), 54: ('하우스베이커리', '2.4', '경기 양평군 서종면 북한강로 684'), 55: ('베니어베이커리카페', '2.4', '경기 시흥시 서해안로 1444-1'), 56: ('내추럴가든529', '3.1', '경기 양평군 서종면 내수입길 108-8'), 57: ('꼬꼬오리주물럭', '3.8', '경기 김포시 양촌읍 흥신로239번길 49 1층, 2층'), 58: ('기와집순두부 조안본점', '3.3', '경기 남양주시 조안면 북한강로 133'), 59: ('심학산도토리국수 본점', '3.7', '경기 파주시 교하로681번길 12'), 60: ('카페산', '3.6', '경기 광주시 남한산성면 검복길 82 1층'), 61: ('이동정원갈비', '4.3', '경기 포천시 이동면 화동로 1970'), 62: ('신라갈비', '2.8', '경기 수원시 영통구 동수원로 538'), 63: ('돼지집 본관', '3.4', '경기 광명시 기아로 56'), 64: ('운멜로 1호점', '3.7', '경기 수원시 팔달구 화서문로32번길 4 2층'), 65: ('포레스트아웃팅스 일산점', '3.1', '경기 고양시 일산동구 고양대로 1124'), 66: ('새소리물소리', '3.6', '경기 성남시 수정구 오야남로38번길 10 1층'), 67: ('개성집', '3.7', '경기 남양주시 와부읍 경강로 876'), 68: ('평양면옥 의정부본점', '3.8', '경기 의정부시 평화로439번길 7'), 69: ('이나경송탄부대찌개', '3.7', '경기 수원시 팔달구 효원로307번길 47 문화빌딩 1층'), 70: ('수수카페', '3.8', '경기 양평군 양서면 북한강로89번길 16'), 71: ('청담추어정', '3.9', '경기 성남시 수정구 여수대로56번길 3'), 72: ('260도 부천점', '4.1', '경기 부천시 신흥로 178 두산위브더스테이트 3단지 216호'), 73: ('한성치킨', '3.1', '경기 김포시 양촌읍 석모로73번길 85 1층'), 74: ('오늘의초밥', '3.9', '경기 수원시 영통구 센트럴파크로127번길 18 1층'), 75: ('선일목장 정육식당', '2.9', '경기 의왕시 백운안길 49'), 76: ('주막보리밥 서오릉본점', '2.9', '경기 고양시 덕양구 용두로47번길 133'), 77: ('본가만두전골전문점', '3.2', '경기 시흥시 동서로811번길 33'), 78: ('보영만두 북문본점', '3.2', '경기 수원시 장안구 팔달로 271 1층'), 79: ('팔당원조칼제비', '2.9', '경기 하남시 검단산로 348 2층 201호'), 80: ('하얀풍차제과 망포역점', '3.8', '경기 ...

# %%
print(len(ka_dict))
# Out:
# 120

# %%
df = pd.DataFrame(ka_dict)

# %%
df.T
# Out:
#              0    1                       2
# 0       카페대너리스  3.8    경기 남양주시 조안면 북한강로 914
# 1        더티트렁크  2.6          경기 파주시 지목로 114
# 2       고기리막국수  3.6     경기 용인시 수지구 이종무로 157
# 3        레드브릿지  3.3   경기 파주시 광탄면 기산로 329 2층
# 4       가보정 1관  3.2     경기 수원시 팔달구 장다리로 282
# ..         ...  ...                     ...
# 115        강이다  3.8  경기 양평군 양서면 북한강로81번길 23
# 116  북극해고등어 본점  4.1    경기 오산시 경기대로 845 지하1층
# 117       물레방아  2.7      경기 화성시 서신면 제부로 461
# 118   원조향토이동갈비  4.7     경기 포천시 일동면 화동로 1182
# 119     강민주의들밥  3.5   경기 이천시 마장면 지산로22번길 17
#
# [120 rows x 3 columns]
