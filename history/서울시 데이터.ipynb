# %%
import urllib.request
import json
import pandas as pd

# %%
url = 'seuol_person activities_20221026151913.csv'
data = pd.read_csv(url)
data
# Out:
#     구분별(1)        구분별(2)  2021   2021.1        2021.2 2021.3 2021.4 2021.5  \
# 0   구분별(1)        구분별(2)    합계  여행야외나들이  컴퓨터게임인터넷검색 등     휴식   사회활동     운동
# 1      서울시            소계  59.5      2.3          11.1   10.4    1.2    6.0
# 2       성별            남자  57.4      2.1          14.0    9.9    0.8    6.3
# 3       성별            여자  61.4      2.4           8.5   10.9    1.6    5.7
# 4      연령별           10대  42.2      1.2          27.8   10.2    1.0    4.9
# 5      연령별           20대  45.3      2.2          24.7    9.3    1.5    5.8
# 6      연령별           30대  54.1      2.5          14.0   11.5    0.7    5.8
# 7      연령별           40대  59.1      2.7           9.1   12.5    0.9    5.3
# 8      연령별           50대  65.2      2.3           5.9   10.2    1.4    6.0
# 9      연령별        60대 이상  71.9      2.0           2.1    9.2    1.4    6.8
# 10     학력별         중졸 이하  71.5      1.4           2.5   10.6    1.6    5.9
# 11     학력별         고졸 이하  65.4      1.8           8.3   10.5    1.0    5.6
# 12     학력별         대졸 이하  54.7      2.5          15.0   10.2    1.3    6.0
# 13     학력별        대학원 이상  50.5      4.1           9.0   11.3    0.8    7.7
# 14     소득별      200만원 미만  67.6      1.7           6.8   11.1    0.8    5.2
# 15     소득별  200-300만원 미만  63.8      2.0          11.0    9.7    0.8    5.0
# 16     소득별  300-400만원 미만  61.6      2.1          10.2    9.6    1.4    5.9
# 17     소득별  400-500만원 미만  59.0      2.6          12.3   10.6    0.8    5.7
# 18     소득별      500만원 이상  55.4      2.5          12.3   10.7    1.5    6.6
# 19   혼인상태별            기혼  63.9      2.5           5.9   10.6    1.4    6.4
# 20   혼인상태별            미혼  49.3      2.1          21.0   10.4    1.0    5.4
# 21   혼인상태별      이혼/사별/기타  72.5      1.7           3.1    9.7    1.2    6.0
# 22   지역대분류           도심권  61.6      2.9           8.9    8.0    1.7    8.3
# 23   지역대분류           동북권  61.3      2.4          10.3   11.0    0.9    5.0
# 24   지역대분류           서북권  63.3      2.3           9.5   11.1    0.8    4.8
# 25   지역대분류           서남권  57.9      2.0          11.9   11.3    0.9    6.2
# 26   지역대분류           동남권  56.3      2.4          12.8    8.5    2.3    7.4
# 27   지역소분류           종로구  60.4      2.9          11.0    9.5    0.7    6.8
# 28   지역소분류            중구  61.3      4.2           8.8    8.6    2.1    6.1
# 29   지역소분류           용산구  62.7      2.3           7.5    6.8    2.2   10.6
# 30   지역소분류           성동구  58.4      2.3           8.2   13.5    1.8    4.8
# 31   지역소분류           광진구  55.0      2.8          11.7    8.3    2.4    9.6
# 32   지역소분류          동대문구  61.9      1.8           9.9   12.3    0.7    4.6
# 33   지역소분류           중랑구  59.7      3.5          11.2   12.0    0.5    3.8
# 34   지역소분류           성북구  66.1      1.8          11.3    9.4    0.3    3.6
# 35   지역소분류           강북구  63.4      2.1           7.3   11.1    1.1    2.6
# 36   지역소분류           도봉구  61.9      1.6          12.1   10.1    0.2    5.3
# 37   지역소분류           노원구  62.2      2.8          10.1   11.5    0.6    5.3
# 38   지역소분류           은평구  59.8      2.5           9.6   14.2    0.5    5.1
# 39   지역소분류          서대문구  65.2      2.1          10.4    8.4    0.9    4.7
# 40   지역소분류           마포구  66.2      2.3           8.6    9.5    1.0    4.5
# 41   지역소분류           양천구  49.2      2.3           9.9   18.2    0.7    9.7
# 42   지역소분류           강서구  60.8      1.8           8.6   11.4    1.4    6.5
# 50     1.9       0.7     2.0    0.6     3.5       -
# 51     2.7       1.0     3.2    0.7     2.0       0

# %%
import matplotlib.pyplot as plt

data.head()
# Out:
#    구분별(1)  구분별(2)  2021   2021.1        2021.2 2021.3 2021.4 2021.5  2021.6  \
# 0  구분별(1)  구분별(2)    합계  여행야외나들이  컴퓨터게임인터넷검색 등     휴식   사회활동     운동  문화예술관람
# 1     서울시      소계  59.5      2.3          11.1   10.4    1.2    6.0     1.9
# 2      성별      남자  57.4      2.1          14.0    9.9    0.8    6.3     1.9
# 3      성별      여자  61.4      2.4           8.5   10.9    1.6    5.7     2.0
# 4     연령별     10대  42.2      1.2          27.8   10.2    1.0    4.9     2.8
#
#      2021.7  2021.8 2021.9 2021.10 2021.11
# 0  창작적 취미활동  운동경기관람   종교활동      독서      기타
# 1       1.1     2.3    0.9     3.0     0.1
# 2       1.1     3.2    0.6     2.5     0.1
# 3       1.1     1.5    1.3     3.5     0.1
# 4       2.1     2.3    0.5     5.1       -

# %%
plt.pcolor(data)

plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 plt.pcolor(data)
#       3 plt.colorbar()
#       4 plt.show()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2704, in pcolor(shading, alpha, norm, cmap, vmin, vmax, data, *args, **kwargs)
#    2700 @_copy_docstring_and_deprecators(Axes.pcolor)
#    2701 def pcolor(
#    2702         *args, shading=None, alpha=None, norm=None, cmap=None,
#    2703         vmin=None, vmax=None, data=None, **kwargs):
# -> 2704     __ret = gca().pcolor(
#    2705         *args, shading=shading, alpha=alpha, norm=norm, cmap=cmap,
#    2706         vmin=vmin, vmax=vmax,
#    2707         **({"data": data} if data is not None else {}), **kwargs)
#    2708     sci(__ret)
#    2709     return __ret
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:5838, in Axes.pcolor(self, shading, alpha, norm, cmap, vmin, vmax, *args, **kwargs)
#    5834     kwargs['antialiaseds'] = False
#    5836 kwargs.setdefault('snap', False)
# -> 5838 collection = mcoll.PolyCollection(
#    5839     verts, array=C, cmap=cmap, norm=norm, alpha=alpha, **kwargs)
#    5840 collection._scale_norm(norm, vmin, vmax)
#    5841 self._pcolor_grid_deprecation_helper()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/collections.py:1187, in PolyCollection.__init__(self, verts, sizes, closed, **kwargs)
#    1167 def __init__(self, verts, sizes=None, closed=True, **kwargs):
#    1168     """
#    1169     Parameters
#    1170     ----------
#    (...)
#    1185         Forwarded to `.Collection`.
#    1186     """
# -> 1187     super().__init__(**kwargs)
#    1188     self.set_sizes(sizes)
#    1189     self.set_verts(verts, closed)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/collections.py:221, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     218 self._transOffset = transOffset
#     220 self._path_effects = None
# --> 221 self.update(kwargs)
#     222 self._paths = None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/artist.py:1066, in Artist.update(self, props)
#    1063             if not callable(func):
#    1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
# -> 1066             ret.append(func(v))
#    1067 if ret:
#    1068     self.pchanged()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/cm.py:477, in ScalarMappable.set_array(self, A)
#     475 A = cbook.safe_masked_invalid(A, copy=True)
#     476 if not np.can_cast(A.dtype, float, "same_kind"):
# --> 477     raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     478                     "converted to float")
#     480 self._A = A
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
# heatmap by plt.pcolor()
plt.pcolor(df)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.title('Heatmap by plt.pcolor()', fontsize=20)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Month', fontsize=14)
plt.colorbar()
plt.show()
